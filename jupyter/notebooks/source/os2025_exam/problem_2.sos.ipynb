# %% [markdown]
# #  問題2

# %% [markdown]
# ##  (1)
# fork-open + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# fork-open + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (2)
# fork-open + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# fork-open + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (3)
# fork-open + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# fork-open + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (4)
# fork-open + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# fork-open + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + malloc-read

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# open-fork + mmap

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION
