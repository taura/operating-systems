# %% [markdown]
# #  問題1

# %% [markdown]
# ##  (1)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (2)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (3)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (4)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (5)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (6)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (7)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (8)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (9)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (10)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (11)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (12)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (13)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (14)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (15)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (16)

# %%
BEGIN SOLUTION
END SOLUTION
%%writefile send_transaction.c

# %% [markdown]
# ##  (17)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (18)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (19)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (20)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (21)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (22)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION
