# %% [markdown]
# #  問題2

# %% [markdown]
# ##  (1)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (2)

# %%
%%writefile scan.c
#include <err.h>
#include <stdio.h>
int main() {
  int x = 0;
  int r = scanf("%d", &x);
  if (r != 1) err(1, "scanf");
  printf("%d\n", x + 1);
  return 0;
}

# %%
BEGIN SOLUTION
END SOLUTION
gcc -Wall -Wextra -o scan scan.c

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (3)

# %%
BEGIN SOLUTION
END SOLUTION
timeout 180 ./scan

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION

# %% [markdown]
# ##  (4)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION
