# %% [markdown]
# #  問題3

# %% [markdown]
# ##  (1)

# %%
BEGIN SOLUTION
END SOLUTION
%%writefile sieve

# %% [markdown]
# ##  (2)

# %%
BEGIN SOLUTION
END SOLUTION
%%writefile prime100

# %% [markdown]
# ##  (3)

# %% [markdown]
# BEGIN SOLUTION
# END SOLUTION
